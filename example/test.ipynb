# %%
import pandas as pd
from easyregression import LinearRegression
from easyregression import LogisticRegression

# %%
data = pd.read_csv("testdata/employees.csv")
LinearRegression(data["Age"], data["AbsentHours"])
# Out:
# f(x) = 4.095990826110502 * x + -110.77665992993721
# R2 = 0.6892886119577792
# f(x) =4.095990826110502* x +-110.77665992993721
# R2 = 0.6892886119577792

# %%
data = pd.read_csv("testdata/voice.csv")
data["label"] = data["label"].map({"male":0, "female":1})
LogisticRegression(data["meanfun"], data["label"])
# Out:
# R2 = 0.9526813880126183
